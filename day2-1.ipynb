# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/User/Desktop/cdac advance modules/pml lecture/class  practice/program_dataset/Housing.csv")

# %%
df
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
df.isnull().sum() #no null values
# Out:
# price       0
# lotsize     0
# bedrooms    0
# bathrms     0
# stories     0
# driveway    0
# recroom     0
# fullbase    0
# gashw       0
# airco       0
# garagepl    0
# prefarea    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     546 non-null    float64
#  1   lotsize   546 non-null    int64
#  2   bedrooms  546 non-null    int64
#  3   bathrms   546 non-null    int64
#  4   stories   546 non-null    int64
#  5   driveway  546 non-null    object
#  6   recroom   546 non-null    object
#  7   fullbase  546 non-null    object
#  8   gashw     546 non-null    object
#  9   airco     546 non-null    object
#  10  garagepl  546 non-null    int64
#  11  prefarea  546 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 51.3+ KB

# %%
df_num=df.select_dtypes(exclude=['object']).copy()
df_obj=df.select_dtypes(include=['object']).copy()

# %%
df_obj
# Out:
#     driveway recroom fullbase gashw airco prefarea
# 0        yes      no      yes    no    no       no
# 1        yes      no       no    no    no       no
# 2        yes      no       no    no    no       no
# 3        yes     yes       no    no    no       no
# 4        yes      no       no    no    no       no
# ..       ...     ...      ...   ...   ...      ...
# 541      yes     yes       no    no   yes       no
# 542      yes      no       no    no   yes       no
# 543      yes     yes       no    no   yes       no
# 544      yes     yes       no    no   yes       no
# 545      yes      no       no    no   yes       no
#
# [546 rows x 6 columns]

# %%
df_obj_new=pd.get_dummies(df_obj,drop_first=True)

# %%
df_new=pd.concat([df_num,df_obj_new],axis=1)

# %%
df_new.head(5)
# Out:
#      price  lotsize  bedrooms  bathrms  stories  garagepl  driveway_yes  \
# 0  42000.0     5850         3        1        2         1             1
# 1  38500.0     4000         2        1        1         0             1
# 2  49500.0     3060         3        1        1         0             1
# 3  60500.0     6650         3        1        2         0             1
# 4  61000.0     6360         2        1        1         0             1
#
#    recroom_yes  fullbase_yes  gashw_yes  airco_yes  prefarea_yes
# 0            0             1          0          0             0
# 1            0             0          0          0             0
# 2            0             0          0          0             0
# 3            1             0          0          0             0
# 4            0             0          0          0             0

# %%
'''from sklearn.preprocessing import LabelEncoder

df_obj['driveway']=LabelEncoder().fit_transform(df_obj['driveway'])

df_obj['recroom']=LabelEncoder().fit_transform(df_obj['recroom'])

df_obj['fullbase']=LabelEncoder().fit_transform(df_obj['fullbase'])

df_obj['gashw']=LabelEncoder().fit_transform(df_obj['gashw'])

df_obj['airco']=LabelEncoder().fit_transform(df_obj['airco'])

df_obj['prefarea']=LabelEncoder().fit_transform(df_obj['prefarea'])'''
#label encoding function should be done only on target variable
# Out:
# "from sklearn.preprocessing import LabelEncoder\n\ndf_obj['driveway']=LabelEncoder().fit_transform(df_obj['driveway'])\n\ndf_obj['recroom']=LabelEncoder().fit_transform(df_obj['recroom'])\n\ndf_obj['fullbase']=LabelEncoder().fit_transform(df_obj['fullbase'])\n\ndf_obj['gashw']=LabelEncoder().fit_transform(df_obj['gashw'])\n\ndf_obj['airco']=LabelEncoder().fit_transform(df_obj['airco'])\n\ndf_obj['prefarea']=LabelEncoder().fit_transform(df_obj['prefarea'])"

# %%
chemP=pd.read_csv("ChemicalProcess.csv")

# %%
chemP
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
chemP.isnull().sum()
# Out:
# Yield                      0
# BiologicalMaterial01       0
# BiologicalMaterial02       0
# BiologicalMaterial03       0
# BiologicalMaterial04       0
# BiologicalMaterial05       0
# BiologicalMaterial06       0
# BiologicalMaterial07       0
# BiologicalMaterial08       0
# BiologicalMaterial09       0
# BiologicalMaterial10       0
# BiologicalMaterial11       0
# BiologicalMaterial12       0
# ManufacturingProcess01     1
# ManufacturingProcess02     3
# ManufacturingProcess03    15
# ManufacturingProcess04     1
# ManufacturingProcess05     1
# ManufacturingProcess06     2
# ManufacturingProcess07     1
# ManufacturingProcess08     1
# ManufacturingProcess09     0
# ManufacturingProcess10     9
# ManufacturingProcess11    10
# ManufacturingProcess12     1
# ManufacturingProcess13     0
# ManufacturingProcess14     1
# ManufacturingProcess15     0
# ManufacturingProcess16     0
# ManufacturingProcess17     0
# ManufacturingProcess18     0
# ManufacturingProcess19     0
# ...

# %%
chemP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 58 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Yield                   176 non-null    float64
#  1   BiologicalMaterial01    176 non-null    float64
#  2   BiologicalMaterial02    176 non-null    float64
#  3   BiologicalMaterial03    176 non-null    float64
#  4   BiologicalMaterial04    176 non-null    float64
#  5   BiologicalMaterial05    176 non-null    float64
#  6   BiologicalMaterial06    176 non-null    float64
#  7   BiologicalMaterial07    176 non-null    float64
#  8   BiologicalMaterial08    176 non-null    float64
#  9   BiologicalMaterial09    176 non-null    float64
#  10  BiologicalMaterial10    176 non-null    float64
#  11  BiologicalMaterial11    176 non-null    float64
#  12  BiologicalMaterial12    176 non-null    float64
#  13  ManufacturingProcess01  175 non-null    float64
# ...

# %%
chemP.fillna(chemP.median(),inplace=True)

# %%
chemP.isnull().sum()
# Out:
# Yield                     0
# BiologicalMaterial01      0
# BiologicalMaterial02      0
# BiologicalMaterial03      0
# BiologicalMaterial04      0
# BiologicalMaterial05      0
# BiologicalMaterial06      0
# BiologicalMaterial07      0
# BiologicalMaterial08      0
# BiologicalMaterial09      0
# BiologicalMaterial10      0
# BiologicalMaterial11      0
# BiologicalMaterial12      0
# ManufacturingProcess01    0
# ManufacturingProcess02    0
# ManufacturingProcess03    0
# ManufacturingProcess04    0
# ManufacturingProcess05    0
# ManufacturingProcess06    0
# ManufacturingProcess07    0
# ManufacturingProcess08    0
# ManufacturingProcess09    0
# ManufacturingProcess10    0
# ManufacturingProcess11    0
# ManufacturingProcess12    0
# ManufacturingProcess13    0
# ManufacturingProcess14    0
# ManufacturingProcess15    0
# ManufacturingProcess16    0
# ManufacturingProcess17    0
# ManufacturingProcess18    0
# ManufacturingProcess19    0
# ManufacturingProcess20    0
# ...

# %%
concrete=pd.read_csv("Concrete_data.csv")

# %%
concrete
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...

# %%
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cement            1030 non-null   float64
#  1   Blast             1030 non-null   float64
#  2   Fly               1030 non-null   float64
#  3   Water             1030 non-null   float64
#  4   Superplasticizer  1030 non-null   float64
#  5   Coarse            1030 non-null   float64
#  6   Fine              1030 non-null   float64
#  7   Age               1030 non-null   int64
#  8   Strength          1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
minmax.fit(concrete)
minmaxconcrete = minmax.transform(concrete)
minmaxconcrete[0:9,]

# OR
#minmaxMilk = minmax.fit_transform(milk)
# Converting numpy array to pandas
concrete = pd.DataFrame(minmaxconcrete,columns=concrete.columns,
                       index=concrete.index)
