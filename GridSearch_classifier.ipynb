# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r"C:/Users/User/Desktop/cdac advance modules/pml lecture/class  practice/program_dataset/BreastCancer.csv")

# %%
dum_df = pd.get_dummies(df1,drop_first=True)
dum_df
# Out:
#          Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0       61634      5             4              3        1       2      2
# 1       63375      9             1              2        6       4     10
# 2       76389     10             4              7        2       2      8
# 3       95719      6            10             10       10       8     10
# 4      128059      1             1              1        1       2      5
# ..        ...    ...           ...            ...      ...     ...    ...
# 694   1369821     10            10             10       10       5     10
# 695   1371026      5            10             10       10       4     10
# 696   1371920      5             1              1        1       2      1
# 697   8233704      4             1              1        1       1      1
# 698  13454352      1             1              3        1       2      1
#
#      BChromatin  NoemN  Mitoses  Class_Malignant
# ...

# %%
X1 = dum_df.iloc[:,:-1]
y1 = dum_df.iloc[:,-1]

# %%
knnc = KNeighborsClassifier()
svc = SVC()

# %%
for clf in(knnc,svc):
    if clf==knnc:
        parameters = {'n_neighbors': np.arange(1,16)}
        kfold = KFold(n_splits=5 , random_state=42,shuffle=True)
        cv = GridSearchCV(knnc, param_grid=parameters,
                  cv=kfold,scoring='roc_auc',verbose=0)
        cv.fit( X1 , y1 )
        print(clf.__class__.__name__,cv.best_params_)
        print(clf.__class__.__name__,cv.best_score_)

    elif clf==svc:
        C_range = np.linspace(0.001,2,10)
        param_grid = dict( C=C_range)
        from sklearn.model_selection import StratifiedKFold
        kfold = StratifiedKFold(n_splits=5, random_state=2020,shuffle=True)
        cv= GridSearchCV(SVC(probability=True,kernel='linear'), 
                       param_grid=param_grid, cv=kfold, 
                       scoring="roc_auc")
        cv.fit( X1 , y1 )
        print(clf.__class__.__name__,cv.best_params_)
        print(clf.__class__.__name__,cv.best_score_)
# Out:
# KNeighborsClassifier {'n_neighbors': 13}
# KNeighborsClassifier 0.5994782391559698
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Admin\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Admin\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
# ...
